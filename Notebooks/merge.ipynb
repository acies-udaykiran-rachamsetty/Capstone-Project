# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
oil= pd.read_csv(r"..\Data\01_raw\oil.csv")
stores = pd.read_csv(r"..\Data\01_raw\stores.csv")
holidays = pd.read_csv(r"..\Data\01_raw\holidays_events.csv")
train = pd.read_csv(r"..\Data\01_raw\train.csv")
transactions = pd.read_csv(r"..\Data\01_raw\transactions.csv")

# %%
# merged train and store using store number
merged_df = pd.merge(train, stores, on='store_nbr', how='outer')

# %%
merged_df.sample(5)
# Out:
#               id        date  store_nbr          family  sales  onpromotion  \
# 813365   1908734  2015-12-10         15        HARDWARE    5.0            0
# 1531840  1695355  2015-08-12         28      GROCERY II    4.0            0
# 658845   2567961  2016-12-15         12      AUTOMOTIVE   15.0            0
# 849159    841338  2014-04-19         16       BEVERAGES  664.0            0
# 2187863  1109555  2014-09-16         40  PREPARED FOODS   38.0            0
#
#                   city                           state type  cluster
# 813365          Ibarra                        Imbabura    C       15
# 1531840      Guayaquil                          Guayas    E       10
# 658845       Latacunga                        Cotopaxi    C       15
# 849159   Santo Domingo  Santo Domingo de los Tsachilas    C        3
# 2187863        Machala                          El Oro    C        3

# %%
merged_df.shape
# Out:
# (3000888, 10)

# %%
# merged (train + store) and oil using date
merged_df = pd.merge(merged_df, oil, on='date', how='outer')

# %%
merged_df
# Out:
#           id        date  store_nbr      family  sales  onpromotion   city  \
# 0        0.0  2013-01-01        1.0  AUTOMOTIVE    0.0          0.0  Quito
# 1        1.0  2013-01-01        1.0   BABY CARE    0.0          0.0  Quito
# 2        2.0  2013-01-01        1.0      BEAUTY    0.0          0.0  Quito
# 3        3.0  2013-01-01        1.0   BEVERAGES    0.0          0.0  Quito
# 4        4.0  2013-01-01        1.0       BOOKS    0.0          0.0  Quito
# ...      ...         ...        ...         ...    ...          ...    ...
# 3000898  NaN  2017-08-25        NaN         NaN    NaN          NaN    NaN
# 3000899  NaN  2017-08-28        NaN         NaN    NaN          NaN    NaN
# 3000900  NaN  2017-08-29        NaN         NaN    NaN          NaN    NaN
# 3000901  NaN  2017-08-30        NaN         NaN    NaN          NaN    NaN
# 3000902  NaN  2017-08-31        NaN         NaN    NaN          NaN    NaN
#
#              state type  cluster  dcoilwtico
# 0        Pichincha    D     13.0         NaN
# 1        Pichincha    D     13.0         NaN
# 2        Pichincha    D     13.0         NaN
# 3        Pichincha    D     13.0         NaN
# 4        Pichincha    D     13.0         NaN
# ...            ...  ...      ...         ...
# 3000898        NaN  NaN      NaN       47.65
# 3000899        NaN  NaN      NaN       46.40
# 3000900        NaN  NaN      NaN       46.46
# 3000901        NaN  NaN      NaN       45.96
# 3000902        NaN  NaN      NaN       47.26
#
# [3000903 rows x 11 columns]

# %%
merged_df.shape
# Out:
# (3000903, 11)

# %%
# merged (train + store + oil) and holidays using date
merged_df = pd.merge(merged_df, holidays, on='date', how='outer')

# %%
merged_df.shape
# Out:
# (3054427, 16)

# %%
merged_df.sample(10)
# Out:
#                 id        date  store_nbr                   family      sales  \
# 2142561  2115523.0  2016-04-05       17.0            PERSONAL CARE    391.000
# 1978009  1951103.0  2016-01-03       53.0             FROZEN FOODS    150.219
# 2768940  2722398.0  2017-03-12       44.0                  PRODUCE  13899.894
# 294843    292789.0  2013-06-14       24.0               GROCERY II     19.000
# 1042326  1026081.0  2014-07-31       49.0                GROCERY I   4346.000
# 1829109  1803887.0  2015-10-12       23.0                    DAIRY    526.000
# 1761959  1736803.0  2015-09-04       40.0               GROCERY II      6.000
# 1162191  1147596.0  2014-10-07        9.0                 LINGERIE     18.000
# 1467862  1448019.0  2015-03-26       38.0                GROCERY I   2646.000
# 1173912  1157667.0  2014-10-13       40.0  PLAYERS AND ELECTRONICS      2.000
#
#          onpromotion       city       state type_x  cluster  dcoilwtico  \
# 2142561          0.0      Quito   Pichincha      C     12.0       34.52
# 1978009          3.0      Manta      Manabi      D     13.0         NaN
# 2768940          1.0      Quito   Pichincha      A      5.0         NaN
# 294843           0.0  Guayaquil      Guayas      D      1.0       97.83
# 1042326          8.0      Quito   Pichincha      A     11.0       98.23
# 1829109          4.0     Ambato  Tungurahua      D      9.0       47.09
# 1761959          0.0    Machala      El Oro      C      3.0       46.02
# 1162191          0.0      Quito   Pichincha      B      6.0       88.89
# 1467862          9.0       Loja        Loja      D      4.0       51.41
# 1173912          0.0    Machala      El Oro      C      3.0       85.73
#
#           type_y locale locale_name               description transferred
# 2142561      NaN    NaN         NaN                       NaN         NaN
# 1978009      NaN    NaN         NaN                       NaN         NaN
# 2768940      NaN    NaN         NaN                       NaN         NaN
# 294843       NaN    NaN         NaN                       NaN         NaN
# 1042326      NaN    NaN         NaN                       NaN         NaN
# 1829109      NaN    NaN         NaN                       NaN         NaN
# 1761959      NaN    NaN         NaN                       NaN         NaN
# 1162191  Holiday  Local     Quevedo  Cantonizacion de Quevedo       False
# 1467862      NaN    NaN         NaN                       NaN         NaN
# 1173912      NaN    NaN         NaN                       NaN         NaN

# %%
# merged (train + store + oil + holidays) and transaction using date + store number
merged_df = pd.merge(merged_df, transactions, on=['date', 'store_nbr'], how='outer')

# %%
merged_df.sample(10)
# Out:
#                 id        date  store_nbr                   family    sales  \
# 527418    520117.0  2013-10-19       52.0                    BOOKS    0.000
# 92132      91893.0  2013-02-21       37.0                 LINGERIE   10.000
# 2494390  2451413.0  2016-10-10       41.0                    DAIRY  730.000
# 2973308  2921354.0  2017-07-02       27.0           PREPARED FOODS  131.894
# 495452    488283.0  2013-10-02        1.0       HOME AND KITCHEN I    0.000
# 2805031  2759644.0  2017-04-02        4.0               LADIESWEAR   41.000
# 2136557  2109651.0  2016-04-01       51.0  PLAYERS AND ELECTRONICS    7.000
# 2525206  2483054.0  2016-10-28        3.0                   BEAUTY   11.000
# 1881542  1856386.0  2015-11-10       46.0                    BOOKS    0.000
# 530027    522627.0  2013-10-21       23.0              CELEBRATION    0.000
#
#          onpromotion       city       state type_x  cluster  dcoilwtico  \
# 527418           0.0      Manta      Manabi      A     11.0         NaN
# 92132            0.0     Cuenca       Azuay      D      2.0       92.79
# 2494390          8.0    Machala      El Oro      D      4.0       49.76
# 2973308          0.0      Daule      Guayas      D      1.0         NaN
# 495452           0.0      Quito   Pichincha      D     13.0      104.15
# 2805031          0.0      Quito   Pichincha      D      9.0         NaN
# 2136557          0.0  Guayaquil      Guayas      A     17.0       35.36
# 2525206          0.0      Quito   Pichincha      D      8.0       48.72
# 1881542          0.0      Quito   Pichincha      A     14.0       44.23
# 530027           0.0     Ambato  Tungurahua      D      9.0       99.28
#
#           type_y    locale locale_name                    description  \
# 527418       NaN       NaN         NaN                            NaN
# 92132        NaN       NaN         NaN                            NaN
# 2494390      NaN       NaN         NaN                            NaN
# 2973308      NaN       NaN         NaN                            NaN
# 495452       NaN       NaN         NaN                            NaN
# 2805031      NaN       NaN         NaN                            NaN
# 2136557  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2525206      NaN       NaN         NaN                            NaN
# 1881542  Holiday     Local    Guaranda      Independencia de Guaranda
# 530027       NaN       NaN         NaN                            NaN
#
#         transferred  transactions
# 527418          NaN           NaN
# 92132           NaN        1380.0
# 2494390         NaN         968.0
# 2973308         NaN        2018.0
# 495452          NaN        1917.0
# 2805031         NaN        1659.0
# 2136557       False        1752.0
# 2525206         NaN        3200.0
# 1881542       False        2679.0
# 530027          NaN        1090.0

# %%
merged_df.shape
# Out:
# (3054427, 17)

# %%
#merged_df.to_csv(r'..\Data\02_intermediate\merged_data.csv')

# %%
merged_df['date'] = pd.to_datetime(merged_df['date'])
merged_df = merged_df[merged_df['date'].dt.year != 2012]

# %%
merged_df = merged_df[merged_df['date'] <= '2017-08-15']

# %%
#merged_df.to_csv(r'..\Data\02_intermediate\merged_data_updated.csv')

# %%
merged_df
# Out:
#                 id       date  store_nbr                      family    sales  \
# 41             0.0 2013-01-01        1.0                  AUTOMOTIVE    0.000
# 42             1.0 2013-01-01        1.0                   BABY CARE    0.000
# 43             2.0 2013-01-01        1.0                      BEAUTY    0.000
# 44             3.0 2013-01-01        1.0                   BEVERAGES    0.000
# 45             4.0 2013-01-01        1.0                       BOOKS    0.000
# ...            ...        ...        ...                         ...      ...
# 3054388  3000751.0 2017-08-15       54.0                     POULTRY   59.619
# 3054389  3000752.0 2017-08-15       54.0              PREPARED FOODS   94.000
# 3054390  3000753.0 2017-08-15       54.0                     PRODUCE  915.371
# 3054391  3000754.0 2017-08-15       54.0  SCHOOL AND OFFICE SUPPLIES    0.000
# 3054392  3000755.0 2017-08-15       54.0                     SEAFOOD    3.000
#
#          onpromotion       city      state type_x  cluster  dcoilwtico  \
# 41               0.0      Quito  Pichincha      D     13.0         NaN
# 42               0.0      Quito  Pichincha      D     13.0         NaN
# 43               0.0      Quito  Pichincha      D     13.0         NaN
# 44               0.0      Quito  Pichincha      D     13.0         NaN
# 45               0.0      Quito  Pichincha      D     13.0         NaN
# ...              ...        ...        ...    ...      ...         ...
# 3054388          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054389          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054390         76.0  El Carmen     Manabi      C      3.0       47.57
# 3054391          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054392          0.0  El Carmen     Manabi      C      3.0       47.57
#
#           type_y    locale locale_name            description transferred  \
# 41       Holiday  National     Ecuador     Primer dia del ano       False
# 42       Holiday  National     Ecuador     Primer dia del ano       False
# 43       Holiday  National     Ecuador     Primer dia del ano       False
# 44       Holiday  National     Ecuador     Primer dia del ano       False
# 45       Holiday  National     Ecuador     Primer dia del ano       False
# ...          ...       ...         ...                    ...         ...
# 3054388  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054389  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054390  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054391  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054392  Holiday     Local    Riobamba  Fundacion de Riobamba       False
#
#          transactions
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# ...               ...
# 3054388         802.0
# 3054389         802.0
# 3054390         802.0
# 3054391         802.0
# 3054392         802.0
#
# [3054352 rows x 17 columns]

# %%
output = []

for column in merged_df.columns:

    null_values  = np.sum(pd.isna(merged_df[column]))
    unique = merged_df[column].nunique()
    column_data_type = merged_df[column].dtype

    output.append([column, null_values, unique, column_data_type])

output_df = pd.DataFrame(output, columns = ['column','null values', 'unique', 'datatype'])

describe_df = merged_df.describe().transpose() 
combine_df = pd.concat([ output_df.set_index('column'), describe_df], axis = 1, join='outer')

combine_df
# Out:
#               null values   unique        datatype      count  \
# id                      4  3000888         float64  3054348.0
# date                    0     1688  datetime64[ns]    3054352
# store_nbr               4       54         float64  3054348.0
# family                  4       33          object        NaN
# sales                   4   379610         float64  3054348.0
# onpromotion             4      362         float64  3054348.0
# city                    4       22          object        NaN
# state                   4       16          object        NaN
# type_x                  4        5          object        NaN
# cluster                 4       17         float64  3054348.0
# dcoilwtico         955156      994         float64  2099196.0
# type_y            2551824        6          object        NaN
# locale            2551824        3          object        NaN
# locale_name       2551824       24          object        NaN
# description       2551824      102          object        NaN
# transferred       2551824        2          object        NaN
# transactions       249121     4993         float64  2805231.0
#
#                                        mean                  min  \
# id                           1504276.775379                  0.0
# date          2015-04-26 12:11:52.533984512  2013-01-01 00:00:00
# store_nbr                              27.5                  1.0
# family                                  NaN                  NaN
# sales                            359.020892                  0.0
# onpromotion                         2.61748                  0.0
# city                                    NaN                  NaN
# state                                   NaN                  NaN
# type_x                                  NaN                  NaN
# cluster                            8.481481                  1.0
# dcoilwtico                        68.015874                26.19
# type_y                                  NaN                  NaN
# locale                                  NaN                  NaN
# locale_name                             NaN                  NaN
# description                             NaN                  NaN
# transferred                             NaN                  NaN
# transactions                    1697.071441                  5.0
#
#                               25%                  50%                  75%  \
# id                      754676.75            1507571.5           2255120.25
# date          2014-03-01 00:00:00  2015-04-28 12:00:00  2016-06-22 00:00:00
# store_nbr                    14.0                 27.5                 41.0
# family                        NaN                  NaN                  NaN
# sales                         0.0                 11.0              196.011
# onpromotion                   0.0                  0.0                  0.0
# city                          NaN                  NaN                  NaN
# state                         NaN                  NaN                  NaN
# type_x                        NaN                  NaN                  NaN
# cluster                       4.0                  8.5                 13.0
# dcoilwtico                  46.41                53.43                95.81
# type_y                        NaN                  NaN                  NaN
# locale                        NaN                  NaN                  NaN
# locale_name                   NaN                  NaN                  NaN
# description                   NaN                  NaN                  NaN
# transferred                   NaN                  NaN                  NaN
# transactions               1046.0               1395.0               2081.0
#
#                               max            std
# id                      3000887.0  866261.012008
# date          2017-08-15 00:00:00            NaN
# store_nbr                    54.0      15.585787
# family                        NaN            NaN
# sales                    124717.0    1107.285897
# onpromotion                 741.0      12.254939
# city                          NaN            NaN
# state                         NaN            NaN
# type_x                        NaN            NaN
# cluster                      17.0       4.649735
# dcoilwtico                 110.62      25.691342
# type_y                        NaN            NaN
# locale                        NaN            NaN
# locale_name                   NaN            NaN
# description                   NaN            NaN
# transferred                   NaN            NaN
# transactions               8359.0     966.831652

# %%
merged_df['dcoilwtico'] = merged_df['dcoilwtico'].interpolate(method='linear')

# %%
merged_df.to_csv(r'..\Data\02_intermediate\merged_data.csv')

# %%
np.sum(pd.isna(merged_df['dcoilwtico']))
# Out:
# np.int64(1782)

# %%
merged_df[merged_df['dcoilwtico'].isna() == True]
# Out:
#           id       date  store_nbr                      family  sales  \
# 41       0.0 2013-01-01        1.0                  AUTOMOTIVE    0.0
# 42       1.0 2013-01-01        1.0                   BABY CARE    0.0
# 43       2.0 2013-01-01        1.0                      BEAUTY    0.0
# 44       3.0 2013-01-01        1.0                   BEVERAGES    0.0
# 45       4.0 2013-01-01        1.0                       BOOKS    0.0
# ...      ...        ...        ...                         ...    ...
# 1818  1645.0 2013-01-01       54.0                     POULTRY    0.0
# 1819  1646.0 2013-01-01       54.0              PREPARED FOODS    0.0
# 1820  1647.0 2013-01-01       54.0                     PRODUCE    0.0
# 1821  1648.0 2013-01-01       54.0  SCHOOL AND OFFICE SUPPLIES    0.0
# 1822  1649.0 2013-01-01       54.0                     SEAFOOD    0.0
#
#       onpromotion       city      state type_x  cluster  dcoilwtico   type_y  \
# 41            0.0      Quito  Pichincha      D     13.0         NaN  Holiday
# 42            0.0      Quito  Pichincha      D     13.0         NaN  Holiday
# 43            0.0      Quito  Pichincha      D     13.0         NaN  Holiday
# 44            0.0      Quito  Pichincha      D     13.0         NaN  Holiday
# 45            0.0      Quito  Pichincha      D     13.0         NaN  Holiday
# ...           ...        ...        ...    ...      ...         ...      ...
# 1818          0.0  El Carmen     Manabi      C      3.0         NaN  Holiday
# 1819          0.0  El Carmen     Manabi      C      3.0         NaN  Holiday
# 1820          0.0  El Carmen     Manabi      C      3.0         NaN  Holiday
# 1821          0.0  El Carmen     Manabi      C      3.0         NaN  Holiday
# 1822          0.0  El Carmen     Manabi      C      3.0         NaN  Holiday
#
#         locale locale_name         description transferred  transactions
# 41    National     Ecuador  Primer dia del ano       False           NaN
# 42    National     Ecuador  Primer dia del ano       False           NaN
# 43    National     Ecuador  Primer dia del ano       False           NaN
# 44    National     Ecuador  Primer dia del ano       False           NaN
# 45    National     Ecuador  Primer dia del ano       False           NaN
# ...        ...         ...                 ...         ...           ...
# 1818  National     Ecuador  Primer dia del ano       False           NaN
# 1819  National     Ecuador  Primer dia del ano       False           NaN
# 1820  National     Ecuador  Primer dia del ano       False           NaN
# 1821  National     Ecuador  Primer dia del ano       False           NaN
# 1822  National     Ecuador  Primer dia del ano       False           NaN
#
# [1782 rows x 17 columns]

# %%
merged_df['dcoilwtico'][41] = 93.14

merged_df
# Out:
# C:\Users\Userp57v\AppData\Local\Temp\ipykernel_17332\3384321688.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   merged_df['dcoilwtico'][41] = 93.14
# C:\Users\Userp57v\AppData\Local\Temp\ipykernel_17332\3384321688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_df['dcoilwtico'][41] = 93.14
#                 id       date  store_nbr                      family    sales  \
# 41             0.0 2013-01-01        1.0                  AUTOMOTIVE    0.000
# 42             1.0 2013-01-01        1.0                   BABY CARE    0.000
# 43             2.0 2013-01-01        1.0                      BEAUTY    0.000
# 44             3.0 2013-01-01        1.0                   BEVERAGES    0.000
# 45             4.0 2013-01-01        1.0                       BOOKS    0.000
# ...            ...        ...        ...                         ...      ...
# 3054388  3000751.0 2017-08-15       54.0                     POULTRY   59.619
# 3054389  3000752.0 2017-08-15       54.0              PREPARED FOODS   94.000
# 3054390  3000753.0 2017-08-15       54.0                     PRODUCE  915.371
# 3054391  3000754.0 2017-08-15       54.0  SCHOOL AND OFFICE SUPPLIES    0.000
# 3054392  3000755.0 2017-08-15       54.0                     SEAFOOD    3.000
#
#          onpromotion       city      state type_x  cluster  dcoilwtico  \
# 41               0.0      Quito  Pichincha      D     13.0       93.14
# 42               0.0      Quito  Pichincha      D     13.0         NaN
# 43               0.0      Quito  Pichincha      D     13.0         NaN
# 44               0.0      Quito  Pichincha      D     13.0         NaN
# 45               0.0      Quito  Pichincha      D     13.0         NaN
# ...              ...        ...        ...    ...      ...         ...
# 3054388          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054389          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054390         76.0  El Carmen     Manabi      C      3.0       47.57
# 3054391          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054392          0.0  El Carmen     Manabi      C      3.0       47.57
#
#           type_y    locale locale_name            description transferred  \
# 41       Holiday  National     Ecuador     Primer dia del ano       False
# 42       Holiday  National     Ecuador     Primer dia del ano       False
# 43       Holiday  National     Ecuador     Primer dia del ano       False
# 44       Holiday  National     Ecuador     Primer dia del ano       False
# 45       Holiday  National     Ecuador     Primer dia del ano       False
# ...          ...       ...         ...                    ...         ...
# 3054388  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054389  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054390  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054391  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054392  Holiday     Local    Riobamba  Fundacion de Riobamba       False
#
#          transactions
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# ...               ...
# 3054388         802.0
# 3054389         802.0
# 3054390         802.0
# 3054391         802.0
# 3054392         802.0
#
# [3054352 rows x 17 columns]

# %%
merged_df.loc[merged_df['date'] == '2013-01-01', 'dcoilwtico'] = merged_df.loc[merged_df['date'] == '2013-01-01', 'dcoilwtico'].fillna(method='ffill')
# Out:
# C:\Users\Userp57v\AppData\Local\Temp\ipykernel_17332\309807455.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_df.loc[merged_df['date'] == '2013-01-01', 'dcoilwtico'] = merged_df.loc[merged_df['date'] == '2013-01-01', 'dcoilwtico'].fillna(method='ffill')

# %%
merged_df[merged_df['date'] == '2013-01-01']
# Out:
#           id       date  store_nbr                      family  sales  \
# 41       0.0 2013-01-01        1.0                  AUTOMOTIVE    0.0
# 42       1.0 2013-01-01        1.0                   BABY CARE    0.0
# 43       2.0 2013-01-01        1.0                      BEAUTY    0.0
# 44       3.0 2013-01-01        1.0                   BEVERAGES    0.0
# 45       4.0 2013-01-01        1.0                       BOOKS    0.0
# ...      ...        ...        ...                         ...    ...
# 1818  1645.0 2013-01-01       54.0                     POULTRY    0.0
# 1819  1646.0 2013-01-01       54.0              PREPARED FOODS    0.0
# 1820  1647.0 2013-01-01       54.0                     PRODUCE    0.0
# 1821  1648.0 2013-01-01       54.0  SCHOOL AND OFFICE SUPPLIES    0.0
# 1822  1649.0 2013-01-01       54.0                     SEAFOOD    0.0
#
#       onpromotion       city      state type_x  cluster  dcoilwtico   type_y  \
# 41            0.0      Quito  Pichincha      D     13.0       93.14  Holiday
# 42            0.0      Quito  Pichincha      D     13.0       93.14  Holiday
# 43            0.0      Quito  Pichincha      D     13.0       93.14  Holiday
# 44            0.0      Quito  Pichincha      D     13.0       93.14  Holiday
# 45            0.0      Quito  Pichincha      D     13.0       93.14  Holiday
# ...           ...        ...        ...    ...      ...         ...      ...
# 1818          0.0  El Carmen     Manabi      C      3.0       93.14  Holiday
# 1819          0.0  El Carmen     Manabi      C      3.0       93.14  Holiday
# 1820          0.0  El Carmen     Manabi      C      3.0       93.14  Holiday
# 1821          0.0  El Carmen     Manabi      C      3.0       93.14  Holiday
# 1822          0.0  El Carmen     Manabi      C      3.0       93.14  Holiday
#
#         locale locale_name         description transferred  transactions
# 41    National     Ecuador  Primer dia del ano       False           NaN
# 42    National     Ecuador  Primer dia del ano       False           NaN
# 43    National     Ecuador  Primer dia del ano       False           NaN
# 44    National     Ecuador  Primer dia del ano       False           NaN
# 45    National     Ecuador  Primer dia del ano       False           NaN
# ...        ...         ...                 ...         ...           ...
# 1818  National     Ecuador  Primer dia del ano       False           NaN
# 1819  National     Ecuador  Primer dia del ano       False           NaN
# 1820  National     Ecuador  Primer dia del ano       False           NaN
# 1821  National     Ecuador  Primer dia del ano       False           NaN
# 1822  National     Ecuador  Primer dia del ano       False           NaN
#
# [1782 rows x 17 columns]

# %%
np.sum(pd.isna(merged_df['dcoilwtico']))
# Out:
# np.int64(0)

# %%
merged_df[merged_df['store_nbr'].isnull() == True]
# Out:
#          id       date  store_nbr family  sales  onpromotion city state  \
# 646907  NaN 2013-12-25        NaN    NaN    NaN          NaN  NaN   NaN
# 1304466 NaN 2014-12-25        NaN    NaN    NaN          NaN  NaN   NaN
# 1962025 NaN 2015-12-25        NaN    NaN    NaN          NaN  NaN   NaN
# 2632058 NaN 2016-12-25        NaN    NaN    NaN          NaN  NaN   NaN
#
#         type_x  cluster  dcoilwtico   type_y    locale locale_name  \
# 646907     NaN      NaN   99.025000  Holiday  National     Ecuador
# 1304466    NaN      NaN   55.145000  Holiday  National     Ecuador
# 1962025    NaN      NaN   37.619647  Holiday  National     Ecuador
# 2632058    NaN      NaN   52.415000  Holiday  National     Ecuador
#
#         description transferred  transactions
# 646907      Navidad       False           NaN
# 1304466     Navidad       False           NaN
# 1962025     Navidad       False           NaN
# 2632058     Navidad       False           NaN

# %%
dropper = list(merged_df[merged_df['id'].isnull() == True].index)
for i in dropper:
    merged_df.drop(index = i , inplace=True)
# merged_df
merged_df[merged_df['id'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [id, date, store_nbr, family, sales, onpromotion, city, state, type_x, cluster, dcoilwtico, type_y, locale, locale_name, description, transferred, transactions]
# Index: []

# %%
merged_df[merged_df['sales'] == 0]
# Out:
#                 id       date  store_nbr                      family  sales  \
# 41             0.0 2013-01-01        1.0                  AUTOMOTIVE    0.0
# 42             1.0 2013-01-01        1.0                   BABY CARE    0.0
# 43             2.0 2013-01-01        1.0                      BEAUTY    0.0
# 44             3.0 2013-01-01        1.0                   BEVERAGES    0.0
# 45             4.0 2013-01-01        1.0                       BOOKS    0.0
# ...            ...        ...        ...                         ...    ...
# 3054377  3000740.0 2017-08-15       54.0             HOME APPLIANCES    0.0
# 3054379  3000742.0 2017-08-15       54.0                  LADIESWEAR    0.0
# 3054380  3000743.0 2017-08-15       54.0             LAWN AND GARDEN    0.0
# 3054386  3000749.0 2017-08-15       54.0                PET SUPPLIES    0.0
# 3054391  3000754.0 2017-08-15       54.0  SCHOOL AND OFFICE SUPPLIES    0.0
#
#          onpromotion       city      state type_x  cluster  dcoilwtico  \
# 41               0.0      Quito  Pichincha      D     13.0       93.14
# 42               0.0      Quito  Pichincha      D     13.0       93.14
# 43               0.0      Quito  Pichincha      D     13.0       93.14
# 44               0.0      Quito  Pichincha      D     13.0       93.14
# 45               0.0      Quito  Pichincha      D     13.0       93.14
# ...              ...        ...        ...    ...      ...         ...
# 3054377          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054379          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054380          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054386          0.0  El Carmen     Manabi      C      3.0       47.57
# 3054391          0.0  El Carmen     Manabi      C      3.0       47.57
#
#           type_y    locale locale_name            description transferred  \
# 41       Holiday  National     Ecuador     Primer dia del ano       False
# 42       Holiday  National     Ecuador     Primer dia del ano       False
# 43       Holiday  National     Ecuador     Primer dia del ano       False
# 44       Holiday  National     Ecuador     Primer dia del ano       False
# 45       Holiday  National     Ecuador     Primer dia del ano       False
# ...          ...       ...         ...                    ...         ...
# 3054377  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054379  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054380  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054386  Holiday     Local    Riobamba  Fundacion de Riobamba       False
# 3054391  Holiday     Local    Riobamba  Fundacion de Riobamba       False
#
#          transactions
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# ...               ...
# 3054377         802.0
# 3054379         802.0
# 3054380         802.0
# 3054386         802.0
# 3054391         802.0
#
# [953741 rows x 17 columns]
